# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
table_imdb = pd.read_html('https://en.wikipedia.org/wiki/Jon_Jones')

# %%
print(f'Total tables: {len(table_imdb)}')
# Out:
# Total tables: 9

# %%
table_imdb = pd.read_html('https://en.wikipedia.org/wiki/Jon_Jones', match='Defended')
len(table_imdb)
# Out:
# 1

# %%
df = table_imdb[0]
df.head(28)
# Out:
#     Res.    Record              Opponent  \
# 0    Win  26–1 (1)        Dominick Reyes
# 1    Win  25–1 (1)         Thiago Santos
# 2    Win  24–1 (1)         Anthony Smith
# 3    Win  23–1 (1)  Alexander Gustafsson
# 4     NC  22–1 (1)        Daniel Cormier
# 5    Win      22–1    Ovince Saint Preux
# 6    Win      21–1        Daniel Cormier
# 7    Win      20–1       Glover Teixeira
# 8    Win      19–1  Alexander Gustafsson
# 9    Win      18–1          Chael Sonnen
# 10   Win      17–1         Vitor Belfort
# 11   Win      16–1          Rashad Evans
# 12   Win      15–1         Lyoto Machida
# 13   Win      14–1       Quinton Jackson
# 14   Win      13–1          Maurício Rua
# 15   Win      12–1            Ryan Bader
# 16   Win      11–1  Vladimir Matyushenko
# 17   Win      10–1          Brandon Vera
# 18  Loss       9–1           Matt Hamill
# 19   Win       9–0          Jake O'Brien
# 20   Win       8–0        Stephan Bonnar
# 21   Win       7–0          André Gusmão
# ...
