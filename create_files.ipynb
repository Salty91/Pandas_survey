# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = (df['Country'] == 'Russian Federation')
russia_df = df.loc[filt]
russia_df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 18          I am not primarily a developer, but I write co...      Yes
# 48                                I code primarily as a hobby      Yes
# 103                               I code primarily as a hobby      Yes
# 113                            I am a developer by profession      Yes
# 135                            I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 18          Less than once a month but more than once per ...
# 48                                                      Never
# 103         Less than once a month but more than once per ...
# 113                                   Less than once per year
# 135                                                     Never
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
russia_df.to_csv('modified_rus.csv')

# %%
russia_df.to_csv('modified_rus.tsv', sep='\t')

# %%
russia_df.to_excel('modified_rus.xlsx')

# %%
test = pd.read_excel('modified_rus.xlsx', index_col='Respondent')

# %%
test
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 18          I am not primarily a developer, but I write co...      Yes
# 48                                I code primarily as a hobby      Yes
# 103                               I code primarily as a hobby      Yes
# 113                            I am a developer by profession      Yes
# 135                            I am a developer by profession      Yes
# ...                                                       ...      ...
# 55885                                                     NaN       No
# 62999                                                     NaN      Yes
# 77968                                                     NaN       No
# 81922                                                     NaN      Yes
# 82805                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
russia_df.to_json('modified_rus.json')

# %%
russia_df.to_json('modified_rus.json', orient='records', lines=True)

# %%
test = pd.read_json('modified_rus.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                                           MainBranch Hobbyist  \
# 0  I am not primarily a developer, but I write co...      Yes
# 1                        I code primarily as a hobby      Yes
# 2                        I code primarily as a hobby      Yes
# 3                     I am a developer by profession      Yes
# 4                     I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0  Less than once a month but more than once per ...
# 1                                              Never
# 2  Less than once a month but more than once per ...
# 3                            Less than once per year
# 4                                              Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://postgres:elzy@localhost:5432/sample_db')

# %%
russia_df.to_sql('sample_table', engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...
